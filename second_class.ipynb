# %% [markdown]
# <a href="https://colab.research.google.com/github/shawkot2004/second-class/blob/main/second_class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello hello hello")
# Out:
# hello hello hello

# %%
print("dhaka")
# Out:
# dhaka
